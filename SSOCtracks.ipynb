# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filepath='img/data/tracks_by_top_ssoc4d_year.csv'
df=pd.read_csv(filepath)

# %%
df
# Out:
#      ssoc4d    tracks_final  year  JOB_POST_ID  scaled_JOB_POST_ID
# 0      3322            data  2018          411                1644
# 1      3322            data  2019         1943                1943
# 2      3322            data  2020         1442                1442
# 3      3322            data  2021         1093                3279
# 4      3322  infrastructure  2018         1177                4708
# ..      ...             ...   ...          ...                 ...
# 115    3999        software  2021         2774                8322
# 116    3999         support  2018         1572                6288
# 117    3999         support  2019         6583                6583
# 118    3999         support  2020         4597                4597
# 119    3999         support  2021         2426                7278
#
# [120 rows x 5 columns]

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots(figsize=(10,5))

ax=sns.lineplot(data=df, x='year', y='scaled_JOB_POST_ID', hue='ssoc4d', style='tracks_final', palette='Set2')

sns.despine(top=True, right=True, left=True, bottom=True)
ax.set_ylim(bottom=0)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xlabel('Year')
plt.ylabel('Number of job postings')
plt.title('Number of job postings requiring each digital skill main track by SSOC4D')
plt.tight_layout()
plt.show()
